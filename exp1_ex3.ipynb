# %% [markdown]
# 3.将图像 A 中心部分选取出来，显示中心部分，并保存为与图像 A 相同格式的图像文件

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread(r'.\image\luna.jpg',1)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(img)

# %%
img.shape
# Out:
# (500, 500, 3)

# %%
cropped = img[100:400,100:400]
plt.axis("off")
plt.imshow(cropped)
